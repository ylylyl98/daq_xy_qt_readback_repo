# %% [markdown]
# # UI measure

# %%
#measurement
# %gui qt
from dual_gate_qt_v18_addstop import launch_in_notebook
mw = launch_in_notebook()
# Out:
# MegaSweep: devices attached (iv=False, lf=False)
# KEITHLEY INSTRUMENTS INC.,MODEL 2401,4612957,B02 Jan 20 2021 10:19:49/B01  /W/N
# :SOUR:FUNC VOLT
# :SENS:FUNC 'CURR'
# :SENS:CURR:PROT 1.00e-06
# SOUR:DEL 0.100
# :SENS:FUNC:CONC ON
# :FORM:ELEM VOLT ,CURR
# :SOUR:VOLT:MODE FIXED
# :SOUR:VOLT:RANG 20
# TRIG:COUN 1
# :OUTP ON
# KEITHLEY INSTRUMENTS INC.,MODEL 2401,4644911,B02 Jan 20 2021 10:19:49/B01  /W/N
# :SOUR:FUNC VOLT
# :SENS:FUNC 'CURR'
# :SENS:CURR:PROT 1.00e-06
# SOUR:DEL 0.100
# :SENS:FUNC:CONC ON
# :FORM:ELEM VOLT ,CURR
# :SOUR:VOLT:MODE FIXED
# :SOUR:VOLT:RANG 20
# TRIG:COUN 1
# :OUTP ON
# x_channel Vbg: value: 1.0
# x_channel Vtg: value: 1.0
# y_channel measured_Vbg: value: 1.0
# y_channel Vbg_leakage: value: 9.984195e-07
# y_channel measured_Vtg: value: 1.0
# y_channel Vtg_leakage: value: 1.000353e-06
# loading experiment successful
# Exposetime(ms): 300.0
# Frame_to_combine:10
# Center Wave Length: 780.0
# Grating: [750 nm,600][1][0]
# Center Wave Length: 780.0
# Grating: [750 nm,600][1][0]
# Exposetime(ms): 200.0
# Frame_to_combine:1
# Center Wave Length: 780.0
# Grating: [750 nm,600][1][0]
# Exposetime(ms): 200.0
# Frame_to_combine:1
# Center Wave Length: 780.0
# Grating: [750 nm,600][1][0]
# Exposetime(ms): 200.0
# Frame_to_combine:1
# variable: ['Vbg']
# start: [1.]
# end: [0.]
# steps: 34
# variable: ['Vtg']
# start: [1.]
# end: [0.]
# steps: 34
# variable: ['Vtg']
# start: [0.]
# end: [-1.]
# steps: 34
# variable: ['Vbg']
# start: [0.]
# end: [-1.]
# steps: 34
# variable: ['Vbg']
# start: [-1.]
# end: [0.]
# steps: 34
# variable: ['Vbg']
# start: [0.]
# end: [1.]
# steps: 34
# variable: ['Vtg']
# start: [-1.]
# end: [0.]
# steps: 34
# variable: ['Vbg']
# start: [1.]
# end: [1.]
# steps: 2
# variable: ['Vbg']
# start: [1.]
# end: [0.]
# steps: 34
# variable: ['Vbg']
# start: [0.]
# end: [-1.]
# steps: 34
# variable: ['Vtg']
# start: [0.]
# end: [1.]
# steps: 34
# variable: ['Vbg']
# start: [-1.]
# end: [-1.]
# steps: 2
# variable: ['Vbg']
# start: [-1.]
# end: [0.]
# steps: 34
# variable: ['Vbg']
# start: [0.]
# end: [1.]
# steps: 34

# %%
#scanner
from daq_xy_qt_readback import launch, run

# Notebook-friendly (non-blocking)
app, win = launch("Dev1", "ao0", "ao1")
